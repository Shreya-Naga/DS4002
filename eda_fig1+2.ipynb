# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#read the csv file
df = pd.read_csv('cdc_npao.csv')
print(list(df.columns))
# Out:
# ['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'Datasource', 'Class', 'Topic', 'Question', 'Data_Value_Unit', 'Data_Value_Type', 'Data_Value', 'Data_Value_Alt', 'Data_Value_Footnote_Symbol', 'Data_Value_Footnote', 'Low_Confidence_Limit', 'High_Confidence_Limit ', 'Sample_Size', 'Total', 'Age(years)', 'Education', 'Gender', 'Income', 'Race/Ethnicity', 'GeoLocation', 'ClassID', 'TopicID', 'QuestionID', 'DataValueTypeID', 'LocationID', 'StratificationCategory1', 'Stratification1', 'StratificationCategoryId1', 'StratificationID1']

# %%
#delete unnecessary columns
df_clean = df.drop(['Data_Value_Unit', 'Data_Value_Type', 'Data_Value_Footnote_Symbol', 'Data_Value_Footnote', 'Low_Confidence_Limit', 'High_Confidence_Limit ', 'Total', 'Race/Ethnicity', 'GeoLocation', 'StratificationCategory1', 'Stratification1', 'StratificationCategoryId1', 'StratificationID1'], axis='columns')

# %%
#Add Region Column
northeast = ["PA", "NJ", "CT", "RI", "MA", "NH", "VT", "NY", "ME"]
south = ["TX", "OK", "AR", "LA", "MS", "AL", "GA", "FL", "SC", "NC", "VA", "DC", "MD", "DE", "WV", "KY", "TN", "AL"]
midwest = ["ND", "SD", "NE", "KS", "MO", "IA", "MN", "WI", "IL", "IN", "MI", "OH"]
west = ["WA", "OR", "CA", "AZ", "NV", "ID", "MT", "WY", "CO", "NM", "UT"]

#method to check which region a state is in
def get_region(state):
    if state in northeast:
        return "Northeast"
    elif state in south:
        return "South"
    elif state in midwest:
        return "Midwest"
    elif state in west:
        return "West"
    else:
        return "Unknown"
    
# Apply the function to create a new 'region' column
df_clean['region'] = df_clean['LocationAbbr'].apply(get_region)
df_clean
# Out:
#        YearStart  YearEnd LocationAbbr LocationDesc  \
# 0           2011     2011           AL      Alabama
# 1           2011     2011           AL      Alabama
# 2           2011     2011           AL      Alabama
# 3           2011     2011           AL      Alabama
# 4           2011     2011           AL      Alabama
# ...          ...      ...          ...          ...
# 48767       2015     2015           PR  Puerto Rico
# 48768       2015     2015           PR  Puerto Rico
# 48769       2015     2015           PR  Puerto Rico
# 48770       2015     2015           PR  Puerto Rico
# 48771       2015     2015           PR  Puerto Rico
#
#                                        Datasource                    Class  \
# 0      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 4      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# ...                                           ...                      ...
# 48767  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 48768  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 48769  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 48770  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 48771  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
#
#                          Topic  \
# 0      Obesity / Weight Status
# 1      Obesity / Weight Status
# 2      Obesity / Weight Status
# 3      Obesity / Weight Status
# 4      Obesity / Weight Status
# ...                        ...
# 48767  Obesity / Weight Status
# 48768  Obesity / Weight Status
# 48769  Obesity / Weight Status
# 48770  Obesity / Weight Status
# 48771  Obesity / Weight Status
#
#                                                 Question  Data_Value  \
# 0      Percent of adults aged 18 years and older who ...        32.0
# 1      Percent of adults aged 18 years and older who ...        32.3
# 2      Percent of adults aged 18 years and older who ...        31.8
# 3      Percent of adults aged 18 years and older who ...        33.6
# 4      Percent of adults aged 18 years and older who ...        32.8
# ...                                                  ...         ...
# 48767  Percent of adults aged 18 years and older who ...         NaN
# 48768  Percent of adults aged 18 years and older who ...         NaN
# 48769  Percent of adults aged 18 years and older who ...         NaN
# 48770  Percent of adults aged 18 years and older who ...         NaN
# 48771  Percent of adults aged 18 years and older who ...        37.6
#
#        Data_Value_Alt  ...  Age(years)              Education  Gender Income  \
# 0                32.0  ...         NaN                    NaN     NaN    NaN
# 1                32.3  ...         NaN                    NaN    Male    NaN
# 2                31.8  ...         NaN                    NaN  Female    NaN
# 3                33.6  ...         NaN  Less than high school     NaN    NaN
# 4                32.8  ...         NaN   High school graduate     NaN    NaN
# ...               ...  ...         ...                    ...     ...    ...
# 48767             NaN  ...         NaN                    NaN     NaN    NaN
# 48768             NaN  ...         NaN                    NaN     NaN    NaN
# 48769             NaN  ...         NaN                    NaN     NaN    NaN
# 48770             NaN  ...         NaN                    NaN     NaN    NaN
# 48771            37.6  ...         NaN                    NaN     NaN    NaN
#
#       ClassID TopicID QuestionID DataValueTypeID LocationID   region
# 0         OWS    OWS1       Q036           VALUE          1    South
# 1         OWS    OWS1       Q036           VALUE          1    South
# 2         OWS    OWS1       Q036           VALUE          1    South
# 3         OWS    OWS1       Q036           VALUE          1    South
# 4         OWS    OWS1       Q036           VALUE          1    South
# ...       ...     ...        ...             ...        ...      ...
# 48767     OWS    OWS1       Q037           VALUE         72  Unknown
# 48768     OWS    OWS1       Q037           VALUE         72  Unknown
# 48769     OWS    OWS1       Q037           VALUE         72  Unknown
# 48770     OWS    OWS1       Q037           VALUE         72  Unknown
# 48771     OWS    OWS1       Q037           VALUE         72  Unknown
#
# [48772 rows x 21 columns]

# %%
df_clean = df_clean.groupby(['region', 'QuestionID'])['Data_Value'].mean()
print(df_clean)
# Out:
# region     QuestionID
# Midwest    Q018          40.721610
#            Q019          26.201435
#            Q036          30.220855
#            Q037          34.754408
#            Q043          49.152974
#            Q044          19.055066
#            Q045          29.918964
#            Q046          28.891868
#            Q047          25.780565
# Northeast  Q018          35.560793
#            Q019          21.852500
#            Q036          26.438732
#            Q037          35.420951
#            Q043          50.842857
#            Q044          20.378171
#            Q045          31.954345
#            Q046          29.921797
#            Q047          25.240897
# South      Q018          43.597973
#            Q019          25.346807
#            Q036          30.709721
#            Q037          34.611488
#            Q043          46.732190
#            Q044          18.385714
#            Q045          28.496799
#            Q046          28.058508
#            Q047          28.416806
# Unknown    Q018          41.468310
#            Q019          23.109155
#            Q036          27.298246
#            Q037          35.544639
#            Q043          52.558657
#            Q044          21.911307
#            Q045          33.615548
#            Q046          31.167138
#            Q047          25.430285
# West       Q018          37.667023
#            Q019          20.684679
#            Q036          26.300141
#            Q037          35.281466
#            Q043          55.319857
#            Q044          22.978478
#            Q045          35.516290
#            Q046          32.123815
#            Q047          21.932603
# Name: Data_Value, dtype: float64

# %%
df_clean = df_clean.reset_index()


specific_question_data = df_clean[df_clean['QuestionID'] == 'Q036']
specific_question_data = specific_question_data.rename(columns={'Data_Value': 'PercentObesity'})


# Plot a bar graph
plt.figure(figsize=(10, 6))
for region in specific_question_data['region'].unique():
    region_data = specific_question_data[specific_question_data['region'] == region]
    plt.bar(region, region_data['PercentObesity'], label=region)

# Add labels and title
plt.xlabel('Region')
plt.ylabel('Percent of Adults with Obesity')
plt.title('Percent of Adults with Obesity in Each Region')
plt.legend()

# Show the plot
plt.show()

# %%
print(df_clean.head())
# Out:
#     region QuestionID  Data_Value
# 0  Midwest       Q018   40.721610
# 1  Midwest       Q019   26.201435
# 2  Midwest       Q036   30.220855
# 3  Midwest       Q037   34.754408
# 4  Midwest       Q043   49.152974

# %%
df_clean = df_clean.reset_index(drop=True)

df_clean
# Out:
#        region QuestionID  Data_Value
# 0     Midwest       Q018   40.721610
# 1     Midwest       Q019   26.201435
# 2     Midwest       Q036   30.220855
# 3     Midwest       Q037   34.754408
# 4     Midwest       Q043   49.152974
# 5     Midwest       Q044   19.055066
# 6     Midwest       Q045   29.918964
# 7     Midwest       Q046   28.891868
# 8     Midwest       Q047   25.780565
# 9   Northeast       Q018   35.560793
# 10  Northeast       Q019   21.852500
# 11  Northeast       Q036   26.438732
# 12  Northeast       Q037   35.420951
# 13  Northeast       Q043   50.842857
# 14  Northeast       Q044   20.378171
# 15  Northeast       Q045   31.954345
# 16  Northeast       Q046   29.921797
# 17  Northeast       Q047   25.240897
# 18      South       Q018   43.597973
# 19      South       Q019   25.346807
# 20      South       Q036   30.709721
# 21      South       Q037   34.611488
# 22      South       Q043   46.732190
# 23      South       Q044   18.385714
# 24      South       Q045   28.496799
# 25      South       Q046   28.058508
# 26      South       Q047   28.416806
# 27    Unknown       Q018   41.468310
# 28    Unknown       Q019   23.109155
# 29    Unknown       Q036   27.298246
# 30    Unknown       Q037   35.544639
# 31    Unknown       Q043   52.558657
# 32    Unknown       Q044   21.911307
# 33    Unknown       Q045   33.615548
# 34    Unknown       Q046   31.167138
# 35    Unknown       Q047   25.430285
# 36       West       Q018   37.667023
# 37       West       Q019   20.684679
# 38       West       Q036   26.300141
# 39       West       Q037   35.281466
# 40       West       Q043   55.319857
# 41       West       Q044   22.978478
# 42       West       Q045   35.516290
# 43       West       Q046   32.123815
# 44       West       Q047   21.932603

# %%
education_questions = df_clean['QuestionID'].unique()
print(education_questions)
# Out:
# ['Q018' 'Q019' 'Q036' 'Q037' 'Q043' 'Q044' 'Q045' 'Q046' 'Q047']

# %%
df_clean
# Out:
#        region QuestionID  Data_Value
# 0     Midwest       Q018   40.721610
# 1     Midwest       Q019   26.201435
# 2     Midwest       Q036   30.220855
# 3     Midwest       Q037   34.754408
# 4     Midwest       Q043   49.152974
# 5     Midwest       Q044   19.055066
# 6     Midwest       Q045   29.918964
# 7     Midwest       Q046   28.891868
# 8     Midwest       Q047   25.780565
# 9   Northeast       Q018   35.560793
# 10  Northeast       Q019   21.852500
# 11  Northeast       Q036   26.438732
# 12  Northeast       Q037   35.420951
# 13  Northeast       Q043   50.842857
# 14  Northeast       Q044   20.378171
# 15  Northeast       Q045   31.954345
# 16  Northeast       Q046   29.921797
# 17  Northeast       Q047   25.240897
# 18      South       Q018   43.597973
# 19      South       Q019   25.346807
# 20      South       Q036   30.709721
# 21      South       Q037   34.611488
# 22      South       Q043   46.732190
# 23      South       Q044   18.385714
# 24      South       Q045   28.496799
# 25      South       Q046   28.058508
# 26      South       Q047   28.416806
# 27    Unknown       Q018   41.468310
# 28    Unknown       Q019   23.109155
# 29    Unknown       Q036   27.298246
# 30    Unknown       Q037   35.544639
# 31    Unknown       Q043   52.558657
# 32    Unknown       Q044   21.911307
# 33    Unknown       Q045   33.615548
# 34    Unknown       Q046   31.167138
# 35    Unknown       Q047   25.430285
# 36       West       Q018   37.667023
# 37       West       Q019   20.684679
# 38       West       Q036   26.300141
# 39       West       Q037   35.281466
# 40       West       Q043   55.319857
# 41       West       Q044   22.978478
# 42       West       Q045   35.516290
# 43       West       Q046   32.123815
# 44       West       Q047   21.932603

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Fruit related question
fruit_data = df_clean[df_clean['QuestionID'] == 'Q018']

# Bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='region', y='Data_Value', data=fruit_data, ci=None)  

plt.xlabel('Region')
plt.ylabel('Average Percent of Adults Who Consume Fruit Less Than One Time Daily')
plt.title('Average Percent of Adults Who Consume Fruit Less Than One Time Daily by Region')


plt.show()
